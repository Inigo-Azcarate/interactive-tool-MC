# %%
import pickle
import os
import pandas as pd
import pandana as pdn
import numpy as np
import folium

# Plot
import matplotlib.pyplot as plt
import matplotlib.pyplot as plot
import seaborn as sns

from geopy.distance import geodesic

import json
import math

from datetime import datetime, timedelta

import datetime

import osmnx as ox
import networkx as nx

# %%
a = [1, 0.7, 0.4, 0.1, 0]
b = [1, 0.8, 0.6, 0.4]

def calcular_distancia(row):
    # Convertir de grados a radianes
    lat1, lon1, lat2, lon2 = map(np.radians, [row['O_lat'], row['O_long'], row['D_lat'], row['D_long']])
    
    # Diferencia de las coordenadas
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # Fórmula de Haversine
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # 6371 km es el radio promedio de la Tierra
    distancia_km = 6371 * c
    return distancia_km

def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    distance = R * c
    distance = distance*1000
    return distance

# DRIVE

networks = dict.fromkeys({
 "walk",
 "drive",
})

for k in networks:
    # print(k)
    networks[k] = pdn.network.Network.from_hdf5(f'networks/{k}_net.h5')

# # TRANSIT

transit = dict.fromkeys({
 "transit_0001",
 "transit_0102",
 "transit_0203", # walk_network because transit is not available
 "transit_0304", # walk_network because transit is not available
 "transit_0405", # walk_network because transit is not available
 "transit_0506",
 "transit_0607",
 "transit_0708",
 "transit_0809",
 "transit_0910",
 "transit_1011",
 "transit_1112",
 "transit_1213",
 "transit_1314",
 "transit_1415",
 "transit_1516",
 "transit_1617",
 "transit_1718",
 "transit_1819",
 "transit_1920",
 "transit_2021",
 "transit_2122",
 "transit_2223",
 "transit_2324",
})

for k in transit:
    # print(k)
    transit[k] = pdn.network.Network.from_hdf5(f'transit_together_24h/{k}.h5')


model_name = "rf_prueba"  # El nombre del modelo que guardaste anteriormente
file_path = os.path.join("models", f'{model_name}.pkl')

with open(file_path, 'rb') as file:
    model = pickle.load(file)

destinations = pd.read_csv('destinations.csv')

# %%
# The dataset has 2500 rows
# 50% can work remotely
# 0 wfm days: 0%
# 1 wfm days: 10%
# 2 wfm days: 20%
# 5 wfm days: 50%, everyone that could wfm

wfm = [0, 1, 2, 3, 4]

aux = pd.read_csv('workers_eskuzaitzeta_2k.csv')
longitud = len(aux)
ten_percent = math.ceil(0.1 * longitud)

trips_ez_wfm_0 = pd.read_csv('workers_eskuzaitzeta_2k.csv')
trips_ez_wfm_1 =  trips_ez_wfm_0.sample(n=(longitud - (1 * ten_percent)))
trips_ez_wfm_2 =  trips_ez_wfm_1.sample(n=(longitud - (1 * 2*ten_percent)))
trips_ez_wfm_3 =  trips_ez_wfm_2.sample(n=(longitud - (1 * 3*ten_percent)))
trips_ez_wfm_4 =  trips_ez_wfm_3.sample(n=(longitud - (1 * 4*ten_percent)))

# %%
len(trips_ez_wfm_4)
# Out:
# 1502

# %%
# TRIPS LAYER

# DRIVE NETWORK

# Configurar osmnx
ox.config(use_cache=True, log_console=True)

# Cargar la red de carreteras para la región de interés
G_D = ox.graph_from_place('Gipuzkoa', network_type='drive', simplify=True)

G_undirected_D = nx.to_undirected(G_D)
G_bidirectional_D = nx.to_networkx_graph(G_undirected_D, create_using=nx.MultiDiGraph)

nodes_D, edges_D = ox.graph_to_gdfs(G_D)
nodes_D = nodes_D.reset_index(drop=False)

coords_D = nodes_D.set_index('osmid')[['x', 'y']].T.apply(tuple).to_dict()

# Agregar las coordenadas como atributos a los nodos en el grafo G
nx.set_node_attributes(G_D, coords_D, 'coords')

# WALK NETWORK

ox.config(use_cache=True, log_console=True)

# Cargar la red de carreteras para la región de interés
G_W = ox.graph_from_place('Gipuzkoa', network_type='walk', simplify=True)

G_undirected_W = nx.to_undirected(G_W)
G_bidirectional_W = nx.to_networkx_graph(G_undirected_W, create_using=nx.MultiDiGraph)

nodes_W, edges_W = ox.graph_to_gdfs(G_W)
nodes_W = nodes_W.reset_index(drop=False)

coords_W = nodes_W.set_index('osmid')[['x', 'y']].T.apply(tuple).to_dict()

# Agregar las coordenadas como atributos a los nodos en el grafo G
nx.set_node_attributes(G_W, coords_W, 'coords')
# Out:
# C:\Users\iazka\AppData\Local\Temp\ipykernel_13924\2352378906.py:6: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   ox.config(use_cache=True, log_console=True)
# C:\Users\iazka\AppData\Local\Temp\ipykernel_13924\2352378906.py:24: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   ox.config(use_cache=True, log_console=True)

# %%
def calculate_segment_info_D(route, departure_time, travel_time):
    segments = []
    time_value = datetime.datetime.strptime(departure_time, '%H:%M')
    current_time = time_value.hour * 3600 + time_value.minute * 60
    time_delta = travel_time * 60 / len(route)
    current_time -= time_delta

    for i in range(len(route)-1):
        start_node = route[i]
        current_time += time_delta
        start_coords = G_D.nodes[start_node]['coords']
        segments.append([start_coords['x'], start_coords['y'], current_time])

    current_time += time_delta    
    end_coords = G_D.nodes[route[-1]]['coords']
    segments.append([end_coords['x'], end_coords['y'], current_time])

    reversed_segments = []
    for i, segment in enumerate(segments[::-1]):
        new_time = segments[i][2]  
        reversed_segments.append([segment[0], segment[1], new_time])

    return reversed_segments

def calculate_segment_info_W(route, departure_time, travel_time):
    segments = []
    time_value = datetime.datetime.strptime(departure_time, '%H:%M')
    current_time = time_value.hour * 3600 + time_value.minute * 60
    time_delta = travel_time * 60 / len(route)
    current_time -= time_delta

    for i in range(len(route)-1):
        start_node = route[i]
        current_time += time_delta
        start_coords = G_W.nodes[start_node]['coords']
        segments.append([start_coords['x'], start_coords['y'], current_time])

    current_time += time_delta    
    end_coords = G_W.nodes[route[-1]]['coords']
    segments.append([end_coords['x'], end_coords['y'], current_time])

    reversed_segments = []
    for i, segment in enumerate(segments[::-1]):
        new_time = segments[i][2] 
        reversed_segments.append([segment[0], segment[1], new_time])

    return reversed_segments

# %%
for remote in wfm:
    if remote == 0:
        workers = trips_ez_wfm_0
    elif remote == 1:
        workers = trips_ez_wfm_1
    elif remote == 2:
        workers = trips_ez_wfm_2
    elif remote == 3:
        workers = trips_ez_wfm_3
    else:
        workers = trips_ez_wfm_4   
        
    for valor in a:

        # Bring trips
        trips_ez = workers

        eliminar = ['Unnamed: 0', 'Com_Ori', 'Com_Des', 'Modo', 'Municipio', 'Motos','Actividad','Año']
        trips_ez = trips_ez.drop(columns=eliminar)

        trips_ez['Hora_Ini_E'] = trips_ez['Hora_Ini'].copy()
        cols = list(trips_ez.columns)
        A_index = cols.index('Hora_Ini')
        cols = cols[:A_index+1] + ['Hora_Ini_E'] + cols[A_index+1:-1]
        trips_ez = trips_ez[cols]

        trips_ez['Hora_Ini'] = pd.to_datetime(trips_ez['Hora_Ini_E'], format='%H:%M') # Probably the first is Hora_Ini_E

        trips_ez['Hora_Ini_E'] = ((trips_ez['Hora_Ini'] - pd.to_datetime('00:00', format='%H:%M')).dt.total_seconds() / 300).astype(int) + 1
        trips_ez['Hora_Ini'] = trips_ez['Hora_Ini'].dt.strftime('%H:%M')

        # Aplicar la función a cada fila
        trips_ez['distancia'] = trips_ez.apply(calcular_distancia, axis=1)
        trips_ez['distancia'] = trips_ez['distancia'] * 1000

        if valor == 0:
            def generar_punto_dentro_circulo(centro_lat, centro_long, radio):
                # Generar ángulo aleatorio
                angulo = np.random.uniform(0, 2 * np.pi)
                
                # Generar distancia aleatoria desde el centro
                # Usar la raíz cuadrada para asegurar una distribución uniforme dentro del círculo
                distancia = np.sqrt(np.random.uniform(0, 1)) * radio
                
                # Convertir polar a cartesiano
                delta_lat = distancia * np.cos(angulo)
                delta_long = distancia * np.sin(angulo)
                
                # Calcular las nuevas coordenadas
                punto_lat = centro_lat + delta_lat
                punto_long = centro_long + delta_long
                
                return punto_lat, punto_long

            # Ejemplo de uso	
            # centro_lat = 43.256347
            # centro_long = -2.033693
            radio = 0.005

            for index, row in trips_ez.iterrows():
                lat, long = generar_punto_dentro_circulo(row['O_lat'], row['O_long'], radio)
                trips_ez.at[index, 'D_lat'] = lat
                trips_ez.at[index, 'D_long'] = long
        else:
            # Su porcentaje
            trips_ez['distancia'] = trips_ez['distancia'] * valor

            # Assign NEW origin
            trips_ez['D_lat'] = np.nan
            trips_ez['D_long'] = np.nan

            for index, row in trips_ez.iterrows():
                distances = haversine(row['O_lat'], row['O_long'], destinations['D_lat'], destinations['D_long'])
                
                within_range = destinations[(distances <= row['distancia'] * 1.3) & (distances >= row['distancia'] * 0.7)]
            
                if not within_range.empty:
                    chosen = within_range.sample(n=1)
                    trips_ez.at[index, 'D_lat'] = chosen['D_lat'].values[0]
                    trips_ez.at[index, 'D_long'] = chosen['D_long'].values[0]

        trips_ez = trips_ez.drop(columns='distancia')
        
        trips_ez = trips_ez.dropna(subset=['D_lat']).reset_index(drop=True)

        # TRAVEL TIMES

        trips_ez["drive_tt"] = networks['drive'].shortest_path_lengths(
                    networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
                    networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
                    imp_name='drive_time_s'
                    )
        trips_ez["drive_tt"] = trips_ez["drive_tt"] / 60 # To min

        trips_ez["distance"] = networks['drive'].shortest_path_lengths(
                    networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
                    networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
                    imp_name='distance'
                    )

        trips_ez["walk_tt"] = networks['walk'].shortest_path_lengths(
                    networks['walk'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
                    networks['walk'].get_node_ids(trips_ez.D_long,trips_ez.D_lat)
                    )
        trips_ez["walk_tt"] = trips_ez["walk_tt"] / 60

        # Add TRANSIT

        for k in transit:
            trips_ez[f"{k}_tt"] = transit[k].shortest_path_lengths(
                    transit[k].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
                    transit[k].get_node_ids(trips_ez.D_long,trips_ez.D_lat)
            )

        def asignar_valor(row):
            if 1 <= row['Hora_Ini_E'] <= 12:
                return row['transit_0001_tt']
            elif 13 <= row['Hora_Ini_E'] <= 24:
                return row['transit_0102_tt']
            elif 25 <= row['Hora_Ini_E'] <= 36:
                return row['transit_0203_tt']
            elif 37 <= row['Hora_Ini_E'] <= 48:
                return row['transit_0304_tt']
            elif 49 <= row['Hora_Ini_E'] <= 60:
                return row['transit_0405_tt']
            elif 61 <= row['Hora_Ini_E'] <= 72:
                return row['transit_0506_tt']
            elif 73 <= row['Hora_Ini_E'] <= 84:
                return row['transit_0607_tt']
            elif 85 <= row['Hora_Ini_E'] <= 96:
                return row['transit_0708_tt']
            elif 97 <= row['Hora_Ini_E'] <= 108:
                return row['transit_0809_tt']
            elif 109 <= row['Hora_Ini_E'] <= 120:
                return row['transit_0910_tt']
            elif 121 <= row['Hora_Ini_E'] <= 132:
                return row['transit_1011_tt']
            elif 133 <= row['Hora_Ini_E'] <= 144:
                return row['transit_1112_tt']
            elif 145 <= row['Hora_Ini_E'] <= 156:
                return row['transit_1213_tt']
            elif 157 <= row['Hora_Ini_E'] <= 168:
                return row['transit_1314_tt']
            elif 169 <= row['Hora_Ini_E'] <= 180:
                return row['transit_1415_tt']
            elif 181 <= row['Hora_Ini_E'] <= 192:
                return row['transit_1516_tt']
            elif 193 <= row['Hora_Ini_E'] <= 204:
                return row['transit_1617_tt']
            elif 205 <= row['Hora_Ini_E'] <= 216:
                return row['transit_1718_tt']
            elif 217 <= row['Hora_Ini_E'] <= 228:
                return row['transit_1819_tt']
            elif 229 <= row['Hora_Ini_E'] <= 240:
                return row['transit_1920_tt']
            elif 241 <= row['Hora_Ini_E'] <= 252:
                return row['transit_2021_tt']
            elif 253 <= row['Hora_Ini_E'] <= 264:
                return row['transit_2122_tt']
            elif 265 <= row['Hora_Ini_E'] <= 276:
                return row['transit_2223_tt']
            elif 277 <= row['Hora_Ini_E'] <= 288:
                return row['transit_2324_tt']
            else:
                return None 

        # Create new column
        trips_ez['transit_tt_gm'] = trips_ez.apply(asignar_valor, axis=1)

        # Don't know why but there are some extreme outliers on drive_tt. 70000 mins?
        trips_ez = trips_ez.loc[trips_ez['drive_tt'] < 200].reset_index(drop=True)

        trips_ez = trips_ez.drop(columns=['transit_1314_tt',
            'transit_2122_tt', 'transit_1617_tt', 'transit_0405_tt',
            'transit_0001_tt', 'transit_1213_tt', 'transit_1415_tt',
            'transit_0910_tt', 'transit_0708_tt', 'transit_1011_tt',
            'transit_0102_tt', 'transit_1516_tt', 'transit_0506_tt',
            'transit_2021_tt', 'transit_2324_tt', 'transit_1819_tt',
            'transit_0203_tt', 'transit_0809_tt', 'transit_1718_tt',
            'transit_2223_tt', 'transit_0304_tt', 'transit_1920_tt',
            'transit_0607_tt', 'transit_1112_tt'])

        trips_ez = trips_ez.loc[trips_ez['transit_tt_gm'] <= 700]
        trips_ez = trips_ez.loc[trips_ez['walk_tt'] <= 2000]
        trips_ez = trips_ez.reset_index(drop=True)

        # COLUMNS ENCODING

        # Codify family type manually

        trips_ez['Tipo_familia'].unique()

        family = {'Tipo': ['Hogar de una persona', 'Otros hogares sin niños', '2 adultos',
            '2 adultos con niño(s)', '1 adulto con niño(s)',
            'Otros hogares con niños'], 'Codigo': [1, 2, 3, 4, 5, 6]}
        family = pd.DataFrame(family)

        trips_ez = pd.merge(trips_ez, family, left_on='Tipo_familia', right_on='Tipo', how='left')
        trips_ez = trips_ez.drop(columns=['Tipo_familia', 'Tipo'])
        trips_ez.rename(columns={'Codigo': 'Tipo_familia'}, inplace=True)

        # Codify Mun_Ori y Mun_Des

        pueblos = pd.read_excel("data_towns.xlsx")
        eliminar = ['Region', 'Latitud', 'Longitud', 'Comarca',
            'Altitud (m.s.n.m.)', 'Superficie (kmÂ²)', 'PoblaciÃ³n (2019)',
            'Densidad (hab./kmÂ²)', 'Incluido']
        pueblos = pueblos.drop(columns=eliminar)

        trips_ez = pd.merge(trips_ez, pueblos, left_on='Mun_Ori', right_on='Town')
        trips_ez = trips_ez.drop(columns=['Town', 'Mun_Ori'])
        trips_ez.rename(columns={'Código': 'Mun_Ori'}, inplace=True)

        trips_ez = pd.merge(trips_ez, pueblos, left_on='Mun_Des', right_on='Town')
        trips_ez = trips_ez.drop(columns=['Town', 'Mun_Des'])
        trips_ez.rename(columns={'Código': 'Mun_Des'}, inplace=True)

        for valor2 in b:

            # Change BRT
            trips_ez_1 = trips_ez.copy()
            trips_ez_1['transit_tt_gm'] = trips_ez_1['transit_tt_gm'] * valor2

            x = np.array(trips_ez_1.drop(columns = ['Hora_Ini', 'Recur', 'Income', 'Income_Percentile', 'Mun_Des', 'Mun_Ori', 'O_long', 'O_lat', 'D_long', 'D_lat']))
            y_pred = model.predict(x)
            trips_ez_1['prediction'] = y_pred

            # unique_labels, counts = np.unique(y_pred, return_counts=True)

            # plt.figure(figsize=(8, 8))
            # plt.pie(counts, labels=unique_labels, autopct='%1.1f%%', startangle=140)
            # plt.title('Mode choice for commuters to Eskuzaitzeta')
            # plt.show()

            # SELECT THE NAMES

            if valor == 1:
                a1 = 1
            elif valor == 0.7:
                a1 = 2
            elif valor == 0.4:
                a1 = 3
            elif valor == 0.1:
                a1 = 4
            else:
                a1 = 5
            b1 = int(valor2 * 100)
            name_arc = f'results2/arcs/arc_layer_{remote}_D{a1}_{b1}.json'
            name_hexagon = f'results2/hexagons/hexagons_layer_{remote}_D{a1}_{b1}.json'
            name_trips = f'results2/trips/trips_layer_{remote}_O{a1}_{b1}.json'
            name = f"results2/dfs/trips_{remote}_D{a1}_{b1}.csv"

            # SAVE DF
            trips_ez_1.to_csv(name)

            # SAVE ARCS
            def determine_inbound(mode):
                if mode == "Car":
                    return 1
                elif mode == "PT":
                    return 2
                elif mode == "Andando":
                    return 3
                else:
                    return 0

            json_list = [
                {
                    "inbound": determine_inbound(row['prediction']),
                    "from": {
                        "coordinates": [row['O_long'], row['O_lat']]
                    },
                    "to": {
                        "coordinates": [row['D_long'], row['D_lat']]
                    }
                } for index, row in trips_ez_1.iterrows()
            ]

            # Save the JSON structure to a file
            with open(name_arc, 'w') as outfile:
                json.dump(json_list, outfile, indent=2)
                
            # SAVE HEXAGONS
            trips_ez_1['COORDINATES'] = trips_ez_1.apply(lambda row: [row['O_long'], row['O_lat']], axis=1)

            coordinates_list = trips_ez_1['COORDINATES'].apply(lambda x: {'COORDINATES': x}).tolist()

            with open(name_hexagon, 'w') as f:
                json.dump(coordinates_list, f)
            
            # SAVE TRIPS_LAYER

            if (b1 == 100 and remote == 0):
                data_to_write = []
                for index, fila in trips_ez_1.iterrows():
                    destino = (fila['O_lat'], fila['O_long'])
                    origen = (fila['D_lat'], fila['D_long'])
                    modo = fila['prediction']

                    try:
                        if modo == 'Andando':
                            orig_node = ox.nearest_nodes(G_W, origen[1], origen[0])
                            dest_node = ox.nearest_nodes(G_W, destino[1], destino[0])
                            ruta = nx.shortest_path(G_W, orig_node, dest_node)
                        else:
                            orig_node = ox.nearest_nodes(G_D, origen[1], origen[0])
                            dest_node = ox.nearest_nodes(G_D, destino[1], destino[0])
                            ruta = nx.shortest_path(G_D, orig_node, dest_node)
                    except nx.NetworkXNoPath:
                        print(orig_node, dest_node)
                        continue

                    if modo == 'Car':
                        travel_time = int(fila['drive_tt'])
                    elif modo == 'PT':
                        travel_time = int(fila['transit_tt_gm'])
                    else: 
                        travel_time = int(fila['walk_tt'])

                    if modo == 'Andando':
                        segments = calculate_segment_info_W(ruta, fila['Hora_Ini'], travel_time)
                    else:
                        segments = calculate_segment_info_D(ruta, fila['Hora_Ini'], travel_time)
                    
                    if modo == 'Car':
                        data_to_write.append({"vendor": 1, "segments": segments})
                    elif modo == 'PT':
                        data_to_write.append({"vendor": 2, "segments": segments})
                    else: 
                        data_to_write.append({"vendor": 3, "segments": segments})

                with open(name_trips, 'w') as file:
                    json.dump(data_to_write, file, indent=None)

            print(remote, a1, b1)
# Out:
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(276517116, 2433423935), (368402714, 2433423935), (2426973897, 2096234886), (457160396, 2433423935), (278499699, 2433423935), (276508401, 2433423935), (316135274, 2433423935), (394688595, 2433423935), (2426973731, 368401592), (1374142788, 2433423935), (1474214073, 2433423935), (540603518, 2433423935), (452242954, 2433423935), (1613640320, 2433423935), (1473425827, 2433423935), (313372259, 2433423935), (2297916928, 2256556014), (311050459, 2433423935), (575085750, 2433423935), (8706879331, 450243591), (476509853, 2433423935), (497654895, 2433423935), (537810326, 2433423935), (362311654, 2433423935), (2512201046, 2433423935), (482708182, 2433423935), (476083606, 2433423935), (2489834439, 2217303748), (338209265, 2433423935), (657781647, 2433423935), (2426062755, 2433423935), (590880308, 2433423935), (311194497, 2433423935), (877459454, 2433423935), (2426973575, 301331148), (476081043, 2433423935), (455598329, 2433423935), (577866022, 2433423935), (9704972826, 2126924651)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(276517116, 2433423935), (368402714, 2433423935), (2426973897, 2096234886), (457160396, 2433423935), (278499699, 2433423935), (276508401, 2433423935), (316135274, 2433423935), (394688595, 2433423935), (2426973731, 368401592), (1374142788, 2433423935), (1474214073, 2433423935), (540603518, 2433423935), (452242954, 2433423935), (1613640320, 2433423935), (1473425827, 2433423935), (313372259, 2433423935), (2297916928, 2256556014), (311050459, 2433423935), (575085750, 2433423935), (8706879331, 450243591), (476509853, 2433423935), (497654895, 2433423935), (537810326, 2433423935), (362311654, 2433423935), (2512201046, 2433423935), (482708182, 2433423935), (476083606, 2433423935), (2489834439, 2217303748), (338209265, 2433423935), (657781647, 2433423935), (2426062755, 2433423935), (590880308, 2433423935), (311194497, 2433423935), (877459454, 2433423935), (2426973575, 301331148), (476081043, 2433423935), (455598329, 2433423935), (577866022, 2433423935), (9704972826, 2126924651)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9711962470, 5320194863), (2222669771, 5320194863), (540699598, 11185664641), (8318571647, 5320194863), (5523250023, 5320194863), (406639144, 11185664641), (4664637737, 5320194863), (507251359, 2325908390), (296368785, 5320194863), (1473465434, 5320194863), (7737507495, 5320194863), (7873749027, 5320194863), (5075681435, 5320194863), (1841686554, 5320194863), (365004811, 5320194863), (5320435027, 2337982389), (9617556915, 5320194863), (10772009937, 5320194863), (1600473403, 11185664641), (3421365468, 11185664641), (370502543, 5320194863), (5981206144, 5320194863), (507251359, 476083604), (4124638376, 11185664641), (5981206103, 5320194863), (2306455997, 10308994426), (365004831, 5320194863), (3371283821, 5320194863), (1374142722, 5320194863), (537810326, 11185664641), (619476896, 5320194863), (365510377, 5320194863), (688739884, 11185664641), (9767849890, 11185664641), (260136305, 5320194863), (365004811, 5320194863), (11222626883, 5320194863), (719695036, 11185664641), (10735257549, 5320194863), (1603457433, 5320194863), (3630206081, 5320194863), (2249271789, 5320194863), (619322279, 4365389203), (317467915, 5320194863), (296377651, 5320194863), (803731934, 5320194863), (7734571176, 11185664641), (2283362714, 5320194863), (1960768270, 5320194863), (5320384502, 5320194863), (2620184472, 5320194863), (10043041051, 5320194863), (3735091678, 10308994426), (1943386392, 5320194863), (2505384217, 5320194863), (654132765, 5320194863), (597111395, 2301572410), (392323290, 5320194863), (259078482, 5320194863), (2478346272, 5320194863), (553311282, 5320194863), (2216300585, 11185664641), (5320384502, 5320194863), (5290419588, 11185664641), (367902370, 5320194863), (8381461785, 5320194863)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49021, 108905), (65650, 108905)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45066, 104950), (61695, 104950)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(48949, 108833), (65578, 108833)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(48907, 108791), (65536, 108791)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45135, 105019), (61764, 105019)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45611, 105495), (62240, 105495)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49156, 109040), (65785, 109040)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49064, 108948), (65693, 108948)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45040, 104924), (61669, 104924)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49151, 109035), (65780, 109035)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49067, 108951), (65696, 108951)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49193, 109077), (65822, 109077)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(48997, 108881), (65626, 108881)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45051, 104935), (61680, 104935)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45850, 105734), (62479, 105734)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(46811, 106695), (63440, 106695)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(47448, 107332), (64077, 107332)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49032, 108916), (65661, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(48617, 108501), (65246, 108501)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49130, 109014), (65759, 109014)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49232, 109116), (65861, 109116)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(45043, 104927), (61672, 104927)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49032, 108916), (65661, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(49140, 109024), (65769, 109024)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 464581244 259184971
# 2433485295 2169249235
# 2096234886 7732350675
# 243631971 7732350675
# 368235568 11463910068
# 2325394439 2420360452
# 365509620 7732350675
# 308459172 7732350675
# 553031285 2380610501
# 2096234886 2169249235
# 365508610 7732350675
# 370568473 2420360452
# 2337992305 2420360452
# 365953435 7732350675
# 488058136 574323525
# 450243591 9724832685
# 618427519 577574915
# 368417844 7732350675
# 2126924651 7732350675
# 259241893 7732350675
# 301135317 7732350675
# 5693936145 7732350675
# 0 1 100
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 1 80
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 1 60
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 1 40
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2426973897, 301331148), (370318355, 2433423935), (2433485680, 2433423935), (370275623, 2433423935), (2345193753, 2433423935), (2426973731, 2325394441), (2297916928, 618427519), (8706879331, 3147974326), (275859802, 2433423935), (537994235, 2433423935), (370275618, 2433423935), (495977951, 2433423935), (2489834439, 3531496950), (585146108, 2433423935), (2420360432, 2433423935), (2426973575, 488026563), (1755796697, 2433423935), (9704972826, 2336831141)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2426973897, 301331148), (370318355, 2433423935), (2433485680, 2433423935), (370275623, 2433423935), (2345193753, 2433423935), (2426973731, 2325394441), (2297916928, 618427519), (8706879331, 3147974326), (275859802, 2433423935), (537994235, 2433423935), (370275618, 2433423935), (495977951, 2433423935), (2489834439, 3531496950), (585146108, 2433423935), (2420360432, 2433423935), (2426973575, 488026563), (1755796697, 2433423935), (9704972826, 2336831141)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(477261799, 5320194863), (4162911292, 5320194863), (2478346272, 5320194863), (2325184051, 5320194863), (1763638407, 5320194863), (2264743575, 5320194863), (482975336, 11185664641), (507454665, 11185664641), (507251359, 11185664641), (2175652010, 5320194863), (5718297802, 5320194863), (621457347, 5320194863), (5320435027, 2325897646), (4973923452, 5320194863), (3421365468, 5320194863), (507251359, 9510113193), (368190364, 5320194863), (10073891891, 5320194863), (260604575, 5320194863), (7593519476, 5320194863), (588169790, 5320194863), (3371283821, 5320194863), (483467472, 5320194863), (10033906635, 5320194863), (2331294803, 5320194863), (497654911, 11185664641), (1891629151, 5320194863), (368190356, 5320194863), (368190336, 5320194863), (667937843, 5320194863), (2264743599, 5320194863), (619322279, 2514233248), (3898364375, 11185664641), (2667010887, 5320194863), (296377651, 5320194863), (260754196, 5320194863), (373482994, 5320194863), (495554123, 11185664641), (450838305, 5320194863), (1841726535, 5320194863), (9954069659, 5320194863), (597111395, 9474353572), (2264743575, 5320194863), (1226034719, 5320194863), (1603470147, 5320194863), (618829719, 11185664641)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 464581244 259184981
# 306095460 2169249235
# 367885644 7732350675
# 339962377 7732350675
# 367885644 7732350675
# 464581244 8303953462
# 464581244 263938958
# 3147974336 11463910068
# 11194856099 2420360452
# 5693936145 7732350675
# 561179419 7732350675
# 464581244 266197247
# 567215442 2380610501
# 464581244 263194409
# 464581244 263196614
# 464581244 263205468
# 464581244 266415611
# 464581244 258984042
# 464581244 2667010861
# 464581244 266415637
# 466072222 2169249235
# 365511625 7732350675
# 491111013 2420360452
# 482767031 2420360452
# 561179419 7732350675
# 464581244 263068642
# 464581244 266415629
# 261612698 574323525
# 368235713 9724832685
# 342035496 577574915
# 368417844 7732350675
# 365508610 7732350675
# 3147974336 7732350675
# 367885644 7732350675
# 339962377 7732350675
# 0 2 100
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 2 80
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 2 60
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 2 40
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2426973897, 487896716), (2433422211, 2433423935), (9505140619, 2433423935), (2426973731, 487896716), (2297916928, 281489066), (8706879331, 365004785), (2489834439, 339956268), (487896798, 2433423935), (2433579603, 2433423935), (2426973575, 308459172), (9704972826, 308459172), (487897356, 2433423935)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2426973897, 487896716), (2433422211, 2433423935), (9505140619, 2433423935), (2426973731, 487896716), (2297916928, 281489066), (8706879331, 365004785), (2489834439, 339956268), (487896798, 2433423935), (2433579603, 2433423935), (2426973575, 308459172), (9704972826, 308459172), (487897356, 2433423935)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2337992303, 5320194863), (368233340, 5320194863), (507251359, 275859866), (4947448138, 5320194863), (2337982385, 5320194863), (5320435027, 8349487226), (9836677913, 5320194863), (2325908389, 5320194863), (2192069347, 5320194863), (9449468553, 11185664641), (368233260, 5320194863), (3470068451, 5320194863), (507251359, 2535196919), (368190364, 5320194863), (3470068451, 5320194863), (368233355, 5320194863), (9836677883, 5320194863), (5186010941, 11185664641), (8646588990, 10308994426), (370248642, 5320194863), (2336839776, 5320194863), (368233355, 5320194863), (368235519, 5320194863), (368233340, 5320194863), (10301299245, 11185664641), (9469664274, 11185664641), (368190356, 5320194863), (3470068451, 5320194863), (9712444429, 5320194863), (2433423415, 11185664641), (2325908389, 5320194863), (368190336, 5320194863), (368190356, 5320194863), (2217023012, 5320194863), (619322279, 3499409288), (368235568, 5320194863), (368190356, 5320194863), (368233340, 5320194863), (9503011983, 11185664641), (2217023017, 5320194863), (3470068451, 5320194863), (5320386287, 5320194863), (1251816448, 5320194863), (370248647, 5320194863), (368190356, 5320194863), (597111395, 275859866), (9778073307, 11185664641), (2216300585, 10308994426)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98189, 108905), (42579, 108905)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(94234, 104950), (38624, 104950)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98117, 108833), (42507, 108833)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98075, 108791), (42465, 108791)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(94303, 105019), (38693, 105019)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(94779, 105495), (39169, 105495)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98324, 109040), (42714, 109040)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98232, 108948), (42622, 108948)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(94208, 104924), (38598, 104924)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98319, 109035), (42709, 109035)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98235, 108951), (42625, 108951)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98361, 109077), (42751, 109077)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98165, 108881), (42555, 108881)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(94219, 104935), (38609, 104935)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(95018, 105734), (39408, 105734)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(95979, 106695), (40369, 106695)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(96616, 107332), (41006, 107332)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98200, 108916), (42590, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(97785, 108501), (42175, 108501)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98298, 109014), (42688, 109014)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98400, 109116), (42790, 109116)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(94211, 104927), (38601, 104927)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98200, 108916), (42590, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(98308, 109024), (42698, 109024)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 464581244 6333340419
# 464581244 296347104
# 464581244 296360768
# 464581244 1327919363
# 464581244 458445546
# 464581244 648995480
# 1611606039 2169249235
# 464581244 276546754
# 362345024 7732350675
# 7667248238 7732350675
# 339961118 7732350675
# 365509620 11463910068
# 308459172 2420360452
# 6663022271 7732350675
# 362311588 7732350675
# 464581244 539515960
# 2029861829 2380610501
# 1313210142 2169249235
# 339961118 7732350675
# 464581244 1600473403
# 308459172 2420360452
# 487896716 2420360452
# 7667248238 7732350675
# 464581244 296365545
# 2225830963 574323525
# 464581244 1549315657
# 464581244 9379963380
# 464581244 540594446
# 464581244 1552840214
# 319788308 9724832685
# 2300635427 577574915
# 2367865521 7732350675
# 362316467 7732350675
# 2367865521 7732350675
# 290711398 7732350675
# 339961118 7732350675
# 0 3 100
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 3 80
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 3 60
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 3 40
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(488374510, 2433423935), (2489834439, 292235592), (488057904, 2433423935), (9704972826, 9510113167)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(488374510, 2433423935), (2489834439, 292235592), (488057904, 2433423935), (9704972826, 9510113167)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5320409393, 5320194863), (299168636, 10308994426), (5320455788, 5320194863), (5320435027, 2325908365), (5320409393, 5320194863), (5320455788, 5320194863), (5320455788, 5320194863), (619322279, 1497218267), (1708226025, 10308994426), (2222671312, 10308994426), (597111395, 370543458)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9093, 108905), (30519, 108905), (44700, 108905)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5138, 104950), (26564, 104950), (40745, 104950)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9021, 108833), (30447, 108833), (44628, 108833)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(8979, 108791), (30405, 108791), (44586, 108791)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5207, 105019), (26633, 105019), (40814, 105019)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5683, 105495), (27109, 105495), (41290, 105495)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9228, 109040), (30654, 109040), (44835, 109040)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9136, 108948), (30562, 108948), (44743, 108948)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5112, 104924), (26538, 104924), (40719, 104924)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9223, 109035), (30649, 109035), (44830, 109035)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9139, 108951), (30565, 108951), (44746, 108951)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9265, 109077), (30691, 109077), (44872, 109077)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9069, 108881), (30495, 108881), (44676, 108881)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5123, 104935), (26549, 104935), (40730, 104935)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5922, 105734), (27348, 105734), (41529, 105734)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(6883, 106695), (28309, 106695), (42490, 106695)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(7520, 107332), (28946, 107332), (43127, 107332)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9104, 108916), (30530, 108916), (44711, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(8689, 108501), (30115, 108501), (44296, 108501)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9202, 109014), (30628, 109014), (44809, 109014)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9304, 109116), (30730, 109116), (44911, 109116)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5115, 104927), (26541, 104927), (40722, 104927)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9104, 108916), (30530, 108916), (44711, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(9212, 109024), (30638, 109024), (44819, 109024)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 715957509 2169249235
# 464581244 277765795
# 464581244 1490686034
# 464581244 588169853
# 464581244 554285618
# 598115523 2380610501
# 304071336 2169249235
# 311194624 7732350675
# 583557614 2420360452
# 464581244 582753558
# 464581244 345269867
# 611351429 574323525
# 2217308259 577574915
# 0 4 100
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 4 80
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 4 60
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0 4 40
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2426973897, 2427035857), (621457309, 1654123298), (374183600, 1654123298), (374183976, 1654123298), (374183976, 1654123298), (8706879142, 8706879316), (374183976, 1654123298), (368402743, 9659586527), (9704972826, 10293191441)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(2426973897, 2427035857), (621457309, 1654123298), (374183600, 1654123298), (374183976, 1654123298), (374183976, 1654123298), (8706879142, 8706879316), (374183976, 1654123298), (368402743, 9659586527), (9704972826, 10293191441)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5032697334, 619322279), (8832056014, 2495674088), (5320386325, 5320194863), (507251359, 4931998371), (4947448138, 5320194863), (5320435027, 5189366346), (10772009937, 834059), (2229167502, 834057), (4947447946, 5320194863), (263205470, 2495674088), (11012217584, 572657275), (2229167504, 834059), (258426162, 572657275), (507251359, 586449383), (458701649, 1497201262), (5320429912, 5320194863), (258372877, 4125463608), (533744619, 4705353770), (2325908389, 5189366346), (1474214073, 3151229043), (5320409403, 5189366346), (619322279, 1490016239), (1831493515, 2495674088), (9675332422, 5189366346), (597111395, 618989789)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111168, 4104), (45350, 4103), (112793, 18795), (45352, 4104), (5933, 18795)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(107213, 149), (41395, 148), (108838, 14840), (41397, 149), (1978, 14840)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111096, 4032), (45278, 4031), (112721, 18723), (45280, 4032), (5861, 18723)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111054, 3990), (45236, 3989), (112679, 18681), (45238, 3990), (5819, 18681)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(107282, 218), (41464, 217), (108907, 14909), (41466, 218), (2047, 14909)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(107758, 694), (41940, 693), (109383, 15385), (41942, 694), (2523, 15385)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111303, 4239), (45485, 4238), (112928, 18930), (45487, 4239), (6068, 18930)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111211, 4147), (45393, 4146), (112836, 18838), (45395, 4147), (5976, 18838)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(107187, 123), (41369, 122), (108812, 14814), (41371, 123), (1952, 14814)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111298, 4234), (45480, 4233), (112923, 18925), (45482, 4234), (6063, 18925)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111214, 4150), (45396, 4149), (112839, 18841), (45398, 4150), (5979, 18841)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111340, 4276), (45522, 4275), (112965, 18967), (45524, 4276), (6105, 18967)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111144, 4080), (45326, 4079), (112769, 18771), (45328, 4080), (5909, 18771)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(107198, 134), (41380, 133), (108823, 14825), (41382, 134), (1963, 14825)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(107997, 933), (42179, 932), (109622, 15624), (42181, 933), (2762, 15624)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(108958, 1894), (43140, 1893), (110583, 16585), (43142, 1894), (3723, 16585)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(109595, 2531), (43777, 2530), (111220, 17222), (43779, 2531), (4360, 17222)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111179, 4115), (45361, 4114), (112804, 18806), (45363, 4115), (5944, 18806)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(110764, 3700), (44946, 3699), (112389, 18391), (44948, 3700), (5529, 18391)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111277, 4213), (45459, 4212), (112902, 18904), (45461, 4213), (6042, 18904)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(111379, 4315), (45561, 4314), (113004, 19006), (45563, 4315), (6144, 19006)]
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44586, 108791)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(40814, 105019)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(41290, 105495)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44835, 109040)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44743, 108948)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(40719, 104924)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44830, 109035)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44746, 108951)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44872, 109077)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44676, 108881)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(40730, 104935)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(41529, 105734)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(42490, 106695)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(43127, 107332)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44711, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44296, 108501)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44809, 109014)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44911, 109116)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(40722, 104927)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44711, 108916)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(44819, 109024)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 4 100
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 4 80
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 4 60
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 4 40
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(11551824590, 9659586529), (9704972826, 301355169), (368402743, 9659586526), (296380718, 1654123298)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(11551824590, 9659586529), (9704972826, 301355169), (368402743, 9659586526), (296380718, 1654123298)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5320384502, 5320165415), (640146915, 638591499), (9675332422, 5189366346), (5320435027, 718975673), (1735586381, 2495674088), (1845928356, 4713648384), (458446702, 1497201262), (9675332422, 5320194862), (1350281516, 8235607128), (5320386287, 5189366346), (597111395, 307977166), (507251359, 307979426), (640112402, 638591499), (1831493432, 2495674087)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28162, 96901)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(79819, 79803), (24207, 92946)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28090, 96829)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28048, 96787)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(79888, 79872), (24276, 93015)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(24752, 93491)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28297, 97036)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28205, 96944)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(79793, 79777), (24181, 92920)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28292, 97031)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28208, 96947)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28334, 97073)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28138, 96877)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(79804, 79788), (24192, 92931)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(24991, 93730)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(25952, 94691)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(26589, 95328)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28173, 96912)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(27758, 96497)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28271, 97010)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28373, 97112)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(79796, 79780), (24184, 92923)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28173, 96912)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(28281, 97020)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 5 100
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 5 80
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 5 60
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 4 5 40

# %%
trips_ez
# Out:
#                      Mun_Ori                 Mun_Des Hora_Ini  Hora_Ini_E  \
# 0     Donostia/San Sebastian              Errenteria    18:00         217
# 1                     Pasaia                Oiartzun    07:45          94
# 2                 Errenteria                    Lezo    06:00          73
# 3                 Errenteria                    Lezo    07:40          93
# 4                    Andoain  Donostia/San Sebastian    16:05         194
# ...                      ...                     ...      ...         ...
# 2501  Donostia/San Sebastian              Errenteria    12:30         151
# 2502              Errenteria  Donostia/San Sebastian    08:30         103
# 2503  Donostia/San Sebastian                 Hernani    08:00          97
# 2504            Lasarte-Oria  Donostia/San Sebastian    16:15         196
# 2505                Oiartzun                  Pasaia    13:00         157
#
#       Recur  Per_hog  Turismos             Tipo_familia  Sexo  Edad  crnt_tur  \
# 0        22        2         2    2 adultos con niño(s)     2     5         1
# 1        22        1         2     Hogar de una persona     2     5         1
# 2        22        2         2    2 adultos con niño(s)     1     4         1
# 3        22        2         3  Otros hogares con niños     1     5         1
# 4        22        2         2    2 adultos con niño(s)     1     5         1
# ...     ...      ...       ...                      ...   ...   ...       ...
# 2501     23        2         2  Otros hogares sin niños     1     5         1
# 2502     22        2         2  Otros hogares sin niños     2     3         1
# 2503     21        2         2  Otros hogares sin niños     1     5         1
# 2504     22        2         3    2 adultos con niño(s)     2     4         1
# 2505     23        2         2  Otros hogares sin niños     1     5         1
#
#          Income  Income_Percentile  O_long  O_lat    D_long      D_lat
# 0     21756.570                  1     NaN    NaN -2.033693  43.256347
# 1     26603.660                  4     NaN    NaN -2.033693  43.256347
# 2     26210.410                  4     NaN    NaN -2.033693  43.256347
# 3     27265.510                  4     NaN    NaN -2.033693  43.256347
# 4     24223.070                  2     NaN    NaN -2.033693  43.256347
# ...         ...                ...     ...    ...       ...        ...
# 2501  23900.470                  2     NaN    NaN -2.033693  43.256347
# 2502  18671.675                  1     NaN    NaN -2.033693  43.256347
# 2503  26243.960                  4     NaN    NaN -2.033693  43.256347
# 2504  25976.260                  3     NaN    NaN -2.033693  43.256347
# 2505  25393.260                  3     NaN    NaN -2.033693  43.256347
#
# [2506 rows x 17 columns]

# %%
# trips_ez_1.iloc[871]
trips_ez.iloc[871]
trips_ez
# Out:
#                      Mun_Ori                 Mun_Des Hora_Ini  Hora_Ini_E  \
# 0     Donostia/San Sebastian              Errenteria    18:00         217
# 1                     Pasaia                Oiartzun    07:45          94
# 2                 Errenteria                    Lezo    06:00          73
# 3                 Errenteria                    Lezo    07:40          93
# 4                    Andoain  Donostia/San Sebastian    16:05         194
# ...                      ...                     ...      ...         ...
# 2499                  Zumaia  Donostia/San Sebastian    06:55          84
# 2501  Donostia/San Sebastian              Errenteria    12:30         151
# 2502              Errenteria  Donostia/San Sebastian    08:30         103
# 2503  Donostia/San Sebastian                 Hernani    08:00          97
# 2505                Oiartzun                  Pasaia    13:00         157
#
#       Recur  Per_hog  Turismos             Tipo_familia  Sexo  Edad  crnt_tur  \
# 0        22        2         2    2 adultos con niño(s)     2     5         1
# 1        22        1         2     Hogar de una persona     2     5         1
# 2        22        2         2    2 adultos con niño(s)     1     4         1
# 3        22        2         3  Otros hogares con niños     1     5         1
# 4        22        2         2    2 adultos con niño(s)     1     5         1
# ...     ...      ...       ...                      ...   ...   ...       ...
# 2499     22        1         3                2 adultos     2     4         1
# 2501     23        2         2  Otros hogares sin niños     1     5         1
# 2502     22        2         2  Otros hogares sin niños     2     3         1
# 2503     21        2         2  Otros hogares sin niños     1     5         1
# 2505     23        2         2  Otros hogares sin niños     1     5         1
#
#          Income  Income_Percentile    O_long      O_lat    D_long      D_lat
# 0     21756.570                  1 -2.020480  43.218011 -2.033693  43.256347
# 1     26603.660                  4 -1.990974  43.297325 -2.033693  43.256347
# 2     26210.410                  4 -1.980494  43.266233 -2.033693  43.256347
# 3     27265.510                  4 -1.973222  43.268221 -2.033693  43.256347
# 4     24223.070                  2 -2.015894  43.256309 -2.033693  43.256347
# ...         ...                ...       ...        ...       ...        ...
# 2499  24284.260                  3 -2.015046  43.310240 -2.033693  43.256347
# 2501  23900.470                  2 -1.982352  43.257274 -2.033693  43.256347
# 2502  18671.675                  1 -1.967724  43.263641 -2.033693  43.256347
# 2503  26243.960                  4 -2.069357  43.268234 -2.033693  43.256347
# 2505  25393.260                  3 -1.953077  43.276944 -2.033693  43.256347
#
# [2340 rows x 17 columns]

# %%
a = 0.4 # Lo que se acerca el origen en distancia: 1, 0.7, 0.4, 0.1, WALK
b = 1 # Lo que se ve reducido el transit_tt_gm (BRT): 1, 0.8, 0.6, 0.4
name = "trips_O3_100"
name_hexagon = f'results/hexagons/hexagons_layer_O3_100.json'
name_arc = f'results/arcs/arc_layer_O3_100.json'

# %%
# Eskuzaitzeta data
trips_ez = pd.read_csv('workers_eskuzaitzeta_2k.csv')

eliminar = ['Unnamed: 0', 'Com_Ori', 'Com_Des', 'Modo', 'Municipio', 'Motos','Actividad','Año']
trips_ez = trips_ez.drop(columns=eliminar)

# Codify hour manually

# Create a copy column

trips_ez['Hora_Ini_E'] = trips_ez['Hora_Ini'].copy()
cols = list(trips_ez.columns)
A_index = cols.index('Hora_Ini')
cols = cols[:A_index+1] + ['Hora_Ini_E'] + cols[A_index+1:-1]
trips_ez = trips_ez[cols]

# Codify it
trips_ez['Hora_Ini'] = pd.to_datetime(trips_ez['Hora_Ini_E'], format='%H:%M') # Probably the first is Hora_Ini_E

# Calculates difference in minutes from "00:00" and divides by 5
trips_ez['Hora_Ini_E'] = ((trips_ez['Hora_Ini'] - pd.to_datetime('00:00', format='%H:%M')).dt.total_seconds() / 300).astype(int) + 1
trips_ez['Hora_Ini'] = trips_ez['Hora_Ini'].dt.strftime('%H:%M')

# %%
# Calcular la distancia original de manera simple

# trips_ez.rename(columns={'distance': 'distancia'}, inplace=True)

def calcular_distancia(row):
    # Convertir de grados a radianes
    lat1, lon1, lat2, lon2 = map(np.radians, [row['O_lat'], row['O_long'], row['D_lat'], row['D_long']])
    
    # Diferencia de las coordenadas
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # Fórmula de Haversine
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # 6371 km es el radio promedio de la Tierra
    distancia_km = 6371 * c
    return distancia_km

# Aplicar la función a cada fila
trips_ez['distancia'] = trips_ez.apply(calcular_distancia, axis=1)
trips_ez['distancia'] = trips_ez['distancia'] * 1000

# %% [markdown]
# ## Assign new origin

# %%
# Su porcentaje
trips_ez['distancia'] = trips_ez['distancia'] * a

# %%
# Buscar los origins que están a esa distancia con un error del 5% y asignar uno random

origins = pd.read_csv('origins.csv')
origins.rename(columns={'D_lat': 'O_lat', 'D_long': 'O_long'}, inplace=True)

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    distance = R * c
    distance = distance*1000
    return distance

trips_ez['O_lat'] = np.nan
trips_ez['O_long'] = np.nan

for index, row in trips_ez.iterrows():
    distances = haversine(row['D_lat'], row['D_long'], origins['O_lat'], origins['O_long'])
    
    within_range = origins[(distances <= row['distancia'] * 1.2) & (distances >= row['distancia'] * 0.8)]
    
    if not within_range.empty:
        chosen = within_range.sample(n=1)
        trips_ez.at[index, 'O_lat'] = chosen['O_lat'].values[0]
        trips_ez.at[index, 'O_long'] = chosen['O_long'].values[0]

trips_ez = trips_ez.drop(columns='distancia')

# %%
filas_con_nan = trips_ez[trips_ez['O_lat'].isna()]
trips_ez = trips_ez.dropna(subset=['O_lat'])

# %% [markdown]
# # Show map

# %%
mapa = folium.Map(location=[43.178928, -2.261074], zoom_start=10.2)

for _, fila in trips_ez.iterrows():
    folium.Marker(
        location=[fila['O_lat'], fila['O_long']],
        popup=f'Lat: {fila["O_lat"]}, Long: {fila["O_long"]}', # Ejemplo de un popup con info
    ).add_to(mapa)
# mapa
mapa.save('trips_O_1.html')

# %% [markdown]
# # Walking distance

# %%
# def generar_punto_dentro_circulo(centro_lat, centro_long, radio):
#     # Generar ángulo aleatorio
#     angulo = np.random.uniform(0, 2 * np.pi)
    
#     # Generar distancia aleatoria desde el centro
#     # Usar la raíz cuadrada para asegurar una distribución uniforme dentro del círculo
#     distancia = np.sqrt(np.random.uniform(0, 1)) * radio
    
#     # Convertir polar a cartesiano
#     delta_lat = distancia * np.cos(angulo)
#     delta_long = distancia * np.sin(angulo)
    
#     # Calcular las nuevas coordenadas
#     punto_lat = centro_lat + delta_lat
#     punto_long = centro_long + delta_long
    
#     return punto_lat, punto_long

# # Ejemplo de uso	
# centro_lat = 43.256347
# centro_long = -2.033693
# radio = 0.005 # Asumiendo que este es un radio adecuado para tus necesidades

# # Generar un punto aleatorio dentro del círculo
# # punto_lat, punto_long = generar_punto_dentro_circulo(centro_lat, centro_long, radio)
# # print(punto_lat, punto_long)

# for index, row in trips_ez.iterrows():
#     lat, long = generar_punto_dentro_circulo(centro_lat, centro_long, radio)
#     trips_ez.at[index, 'O_lat'] = lat
#     trips_ez.at[index, 'O_long'] = long

# %%
# # Define tus puntos del cuadrilátero como una lista de tuplas [(lat, long), ...]
# puntos_cuadrilatero = [(43.259208, -2.037389), (43.258780, -2.024276), (43.251836, -2.037910), (43.251126, -2.027378)]

# # Suponiendo que tienes un DataFrame df con columnas 'O_lat' y 'O_long'
# # df = pd.DataFrame(...)

# # Función para verificar si un punto está dentro de un cuadrilátero
# def punto_dentro_cuadrilatero(x, y, puntos):
#     n = len(puntos)
#     inside = False

#     p1x, p1y = puntos[0]
#     for i in range(n + 1):
#         p2x, p2y = puntos[i % n]
#         if y > min(p1y, p2y):
#             if y <= max(p1y, p2y):
#                 if x <= max(p1x, p2x):
#                     if p1y != p2y:
#                         xints = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
#                     if p1x == p2x or x <= xints:
#                         inside = not inside
#         p1x, p1y = p2x, p2y

#     return inside

# # Función para generar un punto aleatorio dentro del cuadrilátero
# def generar_punto_dentro_cuadrilatero(puntos):
#     min_lat = min(puntos, key=lambda x: x[0])[0]
#     max_lat = max(puntos, key=lambda x: x[0])[0]
#     min_long = min(puntos, key=lambda x: x[1])[1]
#     max_long = max(puntos, key=lambda x: x[1])[1]

#     while True:
#         lat = np.random.uniform(min_lat, max_lat)
#         long = np.random.uniform(min_long, max_long)
#         if punto_dentro_cuadrilatero(lat, long, puntos):
#             return lat, long

# # Asigna un punto aleatorio a cada fila dentro del DataFrame
# for index, row in trips_ez.iterrows():
#     lat, long = generar_punto_dentro_cuadrilatero(puntos_cuadrilatero)
#     trips_ez.at[index, 'O_lat'] = lat
#     trips_ez.at[index, 'O_long'] = long

# %% [markdown]
# ## Add travel times

# %%
# # DRIVE

# networks = dict.fromkeys({
#  "walk",
#  "drive",
# })

# for k in networks:
#     print(k)
#     networks[k] = pdn.network.Network.from_hdf5(f'networks/{k}_net.h5')

# # # TRANSIT

# transit = dict.fromkeys({
#  "transit_0001",
#  "transit_0102",
#  "transit_0203", # walk_network because transit is not available
#  "transit_0304", # walk_network because transit is not available
#  "transit_0405", # walk_network because transit is not available
#  "transit_0506",
#  "transit_0607",
#  "transit_0708",
#  "transit_0809",
#  "transit_0910",
#  "transit_1011",
#  "transit_1112",
#  "transit_1213",
#  "transit_1314",
#  "transit_1415",
#  "transit_1516",
#  "transit_1617",
#  "transit_1718",
#  "transit_1819",
#  "transit_1920",
#  "transit_2021",
#  "transit_2122",
#  "transit_2223",
#  "transit_2324",
# })

# for k in transit:
#     print(k)
#     transit[k] = pdn.network.Network.from_hdf5(f'transit_together_24h/{k}.h5')

# %%
# Assign tt

trips_ez["drive_tt"] = networks['drive'].shortest_path_lengths(
            networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
            imp_name='drive_time_s'
            )
trips_ez["drive_tt"] = trips_ez["drive_tt"] / 60 # To min

trips_ez["distance"] = networks['drive'].shortest_path_lengths(
            networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
            imp_name='distance'
            )

trips_ez["walk_tt"] = networks['walk'].shortest_path_lengths(
            networks['walk'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks['walk'].get_node_ids(trips_ez.D_long,trips_ez.D_lat)
            )
trips_ez["walk_tt"] = trips_ez["walk_tt"] / 60

# Add TRANSIT

for k in transit:
    trips_ez[f"{k}_tt"] = transit[k].shortest_path_lengths(
            transit[k].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            transit[k].get_node_ids(trips_ez.D_long,trips_ez.D_lat)
    )

def asignar_valor(row):
    if 1 <= row['Hora_Ini_E'] <= 12:
        return row['transit_0001_tt']
    elif 13 <= row['Hora_Ini_E'] <= 24:
        return row['transit_0102_tt']
    elif 25 <= row['Hora_Ini_E'] <= 36:
        return row['transit_0203_tt']
    elif 37 <= row['Hora_Ini_E'] <= 48:
        return row['transit_0304_tt']
    elif 49 <= row['Hora_Ini_E'] <= 60:
        return row['transit_0405_tt']
    elif 61 <= row['Hora_Ini_E'] <= 72:
        return row['transit_0506_tt']
    elif 73 <= row['Hora_Ini_E'] <= 84:
        return row['transit_0607_tt']
    elif 85 <= row['Hora_Ini_E'] <= 96:
        return row['transit_0708_tt']
    elif 97 <= row['Hora_Ini_E'] <= 108:
        return row['transit_0809_tt']
    elif 109 <= row['Hora_Ini_E'] <= 120:
        return row['transit_0910_tt']
    elif 121 <= row['Hora_Ini_E'] <= 132:
        return row['transit_1011_tt']
    elif 133 <= row['Hora_Ini_E'] <= 144:
        return row['transit_1112_tt']
    elif 145 <= row['Hora_Ini_E'] <= 156:
        return row['transit_1213_tt']
    elif 157 <= row['Hora_Ini_E'] <= 168:
        return row['transit_1314_tt']
    elif 169 <= row['Hora_Ini_E'] <= 180:
        return row['transit_1415_tt']
    elif 181 <= row['Hora_Ini_E'] <= 192:
        return row['transit_1516_tt']
    elif 193 <= row['Hora_Ini_E'] <= 204:
        return row['transit_1617_tt']
    elif 205 <= row['Hora_Ini_E'] <= 216:
        return row['transit_1718_tt']
    elif 217 <= row['Hora_Ini_E'] <= 228:
        return row['transit_1819_tt']
    elif 229 <= row['Hora_Ini_E'] <= 240:
        return row['transit_1920_tt']
    elif 241 <= row['Hora_Ini_E'] <= 252:
        return row['transit_2021_tt']
    elif 253 <= row['Hora_Ini_E'] <= 264:
        return row['transit_2122_tt']
    elif 265 <= row['Hora_Ini_E'] <= 276:
        return row['transit_2223_tt']
    elif 277 <= row['Hora_Ini_E'] <= 288:
        return row['transit_2324_tt']
    else:
        return None 

# Create new column
trips_ez['transit_tt_gm'] = trips_ez.apply(asignar_valor, axis=1)

# Don't know why but there are some extreme outliers on drive_tt. 70000 mins?
trips_ez = trips_ez.loc[trips_ez['drive_tt'] < 200].reset_index(drop=True)

trips_ez = trips_ez.drop(columns=['transit_1314_tt',
       'transit_2122_tt', 'transit_1617_tt', 'transit_0405_tt',
       'transit_0001_tt', 'transit_1213_tt', 'transit_1415_tt',
       'transit_0910_tt', 'transit_0708_tt', 'transit_1011_tt',
       'transit_0102_tt', 'transit_1516_tt', 'transit_0506_tt',
       'transit_2021_tt', 'transit_2324_tt', 'transit_1819_tt',
       'transit_0203_tt', 'transit_0809_tt', 'transit_1718_tt',
       'transit_2223_tt', 'transit_0304_tt', 'transit_1920_tt',
       'transit_0607_tt', 'transit_1112_tt'])
# Out:
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(3371283770, 9712524211), (368403360, 9712524211), (243631223, 9712524211), (60668378, 9712524211)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(3371283770, 9712524211), (368403360, 9712524211), (243631223, 9712524211), (60668378, 9712524211)]
#   warnings.warn(
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandana\network.py:334: UserWarning: Unsigned integer: shortest path distance is trying to be calculated                 between the following external unconnected nodes: [(5075681435, 11221950555), (370248642, 11221950555)]
#   warnings.warn(

# %%
trips_ez = trips_ez.loc[trips_ez['transit_tt_gm'] <= 700]
trips_ez = trips_ez.loc[trips_ez['walk_tt'] <= 2000]
trips_ez = trips_ez.reset_index(drop=True)

# %% [markdown]
# ## Columns encoding

# %%
# Codify family type manually

trips_ez['Tipo_familia'].unique()

family = {'Tipo': ['Hogar de una persona', 'Otros hogares sin niños', '2 adultos',
       '2 adultos con niño(s)', '1 adulto con niño(s)',
       'Otros hogares con niños'], 'Codigo': [1, 2, 3, 4, 5, 6]}
family = pd.DataFrame(family)

trips_ez = pd.merge(trips_ez, family, left_on='Tipo_familia', right_on='Tipo', how='left')
trips_ez = trips_ez.drop(columns=['Tipo_familia', 'Tipo'])
trips_ez.rename(columns={'Codigo': 'Tipo_familia'}, inplace=True)

# Codify Mun_Ori y Mun_Des

pueblos = pd.read_excel("data_towns.xlsx")
eliminar = ['Region', 'Latitud', 'Longitud', 'Comarca',
       'Altitud (m.s.n.m.)', 'Superficie (kmÂ²)', 'PoblaciÃ³n (2019)',
       'Densidad (hab./kmÂ²)', 'Incluido']
pueblos = pueblos.drop(columns=eliminar)

trips_ez = pd.merge(trips_ez, pueblos, left_on='Mun_Ori', right_on='Town')
trips_ez = trips_ez.drop(columns=['Town', 'Mun_Ori'])
trips_ez.rename(columns={'Código': 'Mun_Ori'}, inplace=True)

trips_ez = pd.merge(trips_ez, pueblos, left_on='Mun_Des', right_on='Town')
trips_ez = trips_ez.drop(columns=['Town', 'Mun_Des'])
trips_ez.rename(columns={'Código': 'Mun_Des'}, inplace=True)

# %% [markdown]
# # Predict

# %%
model_name = "rf"  # El nombre del modelo que guardaste anteriormente
file_path = os.path.join("models", f'{model_name}.pkl')

with open(file_path, 'rb') as file:
    model = pickle.load(file)
# Out:
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.3.0 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Change BRT

trips_ez_1 = trips_ez.copy()
trips_ez_1['transit_tt_gm'] = trips_ez_1['transit_tt_gm'] * 1

x = np.array(trips_ez_1.drop(columns = ['Hora_Ini', 'Recur', 'Income', 'Income_Percentile', 'Mun_Des', 'Mun_Ori', 'O_long', 'O_lat', 'D_long', 'D_lat']))
y_pred = model.predict(x)
trips_ez_1['prediction'] = y_pred

unique_labels, counts = np.unique(y_pred, return_counts=True)

plt.figure(figsize=(8, 8))
plt.pie(counts, labels=unique_labels, autopct='%1.1f%%', startangle=140)
plt.title('Mode choice for commuters to Eskuzaitzeta')
plt.show()
# Out:
# c:\Users\iazka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
trips_ez_1.to_csv(f"results/dfs/{name}.csv")

# %% [markdown]
# ## CREACIÓN DE ARCHIVOS HEXAGON Y ARCS

# %%
# Hexagon

trips_ez_1['COORDINATES'] = trips_ez_1.apply(lambda row: [row['O_long'], row['O_lat']], axis=1)

coordinates_list = trips_ez_1['COORDINATES'].apply(lambda x: {'COORDINATES': x}).tolist()

with open(name_hexagon, 'w') as f:
    json.dump(coordinates_list, f)

# %%
# Arcs

def determine_inbound(mode):
    if mode == "Car":
        return 1
    elif mode == "PT":
        return 2
    elif mode == "Andando":
        return 3
    else:
        return 0

json_list = [
    {
        "inbound": determine_inbound(row['prediction']),
        "from": {
            "coordinates": [row['O_long'], row['O_lat']]
        },
        "to": {
            "coordinates": [row['D_long'], row['D_lat']]
        }
    } for index, row in trips_ez_1.iterrows()
]

# Save the JSON structure to a file
with open(name_arc, 'w') as outfile:
    json.dump(json_list, outfile, indent=2)
